# %%
from PIL import Image
import os
import zipfile

def convert_and_resize(image_path, output_dir):
    image = Image.open(image_path)
    base_name = os.path.splitext(os.path.basename(image_path))[0]
    resized_image = image.resize((512, 512))
    output_path = os.path.join(output_dir, f"{base_name}.png")
    resized_image.save(output_path, format="PNG")
    return base_name, image, output_path

def generate_tiles(full_image, row, col, layer, output_dir):
    tile_size = 512
    scale = 3 ** layer
    grid_size = scale
    full_crop_size = tile_size * grid_size
    resized_image = full_image.resize((full_crop_size, full_crop_size))

    tiles = []
    for i in range(grid_size):
        for j in range(grid_size):
            left = j * tile_size
            upper = i * tile_size
            right = left + tile_size
            lower = upper + tile_size
            tile = resized_image.crop((left, upper, right, lower))
            global_row = row * grid_size + i
            global_col = col * grid_size + j
            filename = f"{global_row}_{global_col}.png"
            tile_path = os.path.join(output_dir, filename)
            tile.save(tile_path)
            tiles.append(tile_path)
    return tiles

def zip_tiles(tile_paths, zip_name):
    with zipfile.ZipFile(zip_name, 'w') as zipf:
        for path in tile_paths:
            arcname = os.path.basename(path)
            zipf.write(path, arcname=arcname)
    return zip_name

def infer_coordinates_from_filename(filename):
    base = os.path.splitext(os.path.basename(filename))[0]
    parts = base.split("_")
    if len(parts) != 2 or not all(part.isdigit() for part in parts):
        raise ValueError("Filename must be in the format row_col.ext")
    return int(parts[0]), int(parts[1])

# === Example usage ===
# Update these paths accordingly:
#image_path = "./originals/0_0.png"  # Input image filename
image_path = "C:/Users/brian/Documents/Tiled Images/thangka/originals/4_13.png"
output_base_dir = "C:/Users/brian/Documents/Tiled Images/thangka/output"
os.makedirs(output_base_dir, exist_ok=True)

# Step 1: Convert & Resize
row, col = infer_coordinates_from_filename(image_path)
layer = 1  # Layer of the input image
base_name, full_image, resized_path = convert_and_resize(image_path, output_base_dir)
print(f"Resized image saved to: {resized_path}")

# Step 2: Generate tiles
if layer <= 2:
    tiles_layer_3 = generate_tiles(full_image, row, col, 2, os.path.join(output_base_dir, "Layer+1"))
    #zip_tiles(tiles_layer_3, os.path.join(output_base_dir, "layer_3.zip"))

if layer == 1:
    tiles_layer_2 = generate_tiles(full_image, row, col, 1, os.path.join(output_base_dir, "Layer+2"))
    #zip_tiles(tiles_layer_2, os.path.join(output_base_dir, "layer_2.zip"))

print("Tile generation complete.")

# %%
# Out:
# Resized image saved to: C:/Users/brian/Documents/Tiled Images/thangka/output\4_13.png
# Tile generation complete.

# %%
from PIL import Image
import os

# ==== CONFIGURATION ====
max_layers = 5
input_image_path = r"C:\Users\brian\Documents\Tiled Images\thangka\originals\layer_2\7_4.png"
output_base_path = r"C:\Users\brian\Documents\Tiled Images\thangka\python output"

tile_size = 512
scale_factor = 3  # Each layer increases by 3x per axis


def infer_coordinates_from_filename(filename):
    """Extract row and col from a filename like 6_7.png"""
    base = os.path.splitext(os.path.basename(filename))[0]
    row, col = map(int, base.split("_"))
    return row, col


def ensure_dir(path):
    os.makedirs(path, exist_ok=True)


def crop_tile(original_img, x_index, y_index, crop_size, final_layer):
    """Crop from original image and resize to 512x512"""
    left = x_index * crop_size
    upper = y_index * crop_size
    right = left + crop_size
    lower = upper + crop_size

    tile = original_img.crop((left, upper, right, lower)).resize((tile_size, tile_size), Image.LANCZOS)
    return tile


def generate_all_layers(original_img, start_row, start_col, starting_layer):
    """Recursively generate tile grids from original image through max_layers"""

    for layer in range(starting_layer, max_layers + 1):
        depth = layer - starting_layer
        grid_size = scale_factor ** depth
        crop_size = original_img.width // grid_size

        output_dir = os.path.join(output_base_path, f"layer_{layer}")
        ensure_dir(output_dir)

        for i in range(grid_size):
            for j in range(grid_size):
                global_row = start_row * grid_size + i
                global_col = start_col * grid_size + j

                tile = crop_tile(original_img, j, i, crop_size, layer)
                filename = f"{global_row}_{global_col}.png"
                tile.save(os.path.join(output_dir, filename))


def main():
    # Step 1: Load original image and get row/col
    original_img = Image.open(input_image_path)
    row, col = infer_coordinates_from_filename(input_image_path)

    # Step 2: Save resized 512×512 version to its layer_{N} folder
    starting_layer = int(os.path.basename(os.path.dirname(input_image_path)).split("_")[1])
    resized = original_img.resize((tile_size, tile_size), Image.LANCZOS)
    layer_dir = os.path.join(output_base_path, f"layer_{starting_layer}")
    ensure_dir(layer_dir)
    resized.save(os.path.join(layer_dir, f"{row}_{col}.png"))

    # Step 3: Generate child layers recursively from original image
    generate_all_layers(original_img, row, col, starting_layer)

    print(f"Finished processing {input_image_path} through layer {max_layers}.")


if __name__ == "__main__":
    main()
# Out:
# Finished processing C:\Users\brian\Documents\Tiled Images\thangka\originals\layer_2\7_4.png through layer 5.

# %%
from PIL import Image
import os
import shutil
import re

# === CONFIGURATION ===
max_layers = 5
originals_root = r"C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals"
output_root = r"C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles"
tile_size = 512
scale_factor = 3


def infer_coordinates_from_filename(filename):
    base = os.path.splitext(os.path.basename(filename))[0]
    row, col = map(int, base.split("_"))
    return row, col


def ensure_dir(path):
    os.makedirs(path, exist_ok=True)


def crop_tile(original_img, x_index, y_index, crop_size):
    left = x_index * crop_size
    upper = y_index * crop_size
    right = left + crop_size
    lower = upper + crop_size

    tile = original_img.crop((left, upper, right, lower)).resize((tile_size, tile_size), Image.LANCZOS)
    return tile


def generate_tiles(original_img, start_row, start_col, input_layer):
    """
    Generate tiles starting from layer input_layer + 1 up to max_layers.
    Tile generation is always based on the original image.
    """
    max_layer_for_this_image = max(input_layer + 2, max_layers)
    for layer in range(input_layer + 1, max_layer_for_this_image + 1):
        depth = layer - input_layer  # relative depth
        grid_size = scale_factor ** depth
        crop_size = original_img.width // grid_size
        output_dir = os.path.join(output_root, f"layer_{layer}")
        ensure_dir(output_dir)

        total_tiles = grid_size * grid_size
        print(f"  🔸 Generating {total_tiles} tiles for layer_{layer} ({grid_size}×{grid_size})")

        for i in range(grid_size):
            for j in range(grid_size):
                global_row = start_row * grid_size + i
                global_col = start_col * grid_size + j

                tile = crop_tile(original_img, j, i, crop_size)
                filename = f"{global_row}_{global_col}.png"
                tile.save(os.path.join(output_dir, filename))


def process_image(image_path, layer):
    try:
        print(f"\n🖼️ Processing {image_path} (layer_{layer})")
        original_img = Image.open(image_path)
        row, col = infer_coordinates_from_filename(image_path)

        # Step 1: Resize and save to its own layer
        resized = original_img.resize((tile_size, tile_size), Image.LANCZOS)
        layer_output = os.path.join(output_root, f"layer_{layer}")
        ensure_dir(layer_output)
        resized_path = os.path.join(layer_output, f"{row}_{col}.png")
        resized.save(resized_path)
        print(f"  ✅ Resized saved: {resized_path}")

        # Step 2: Tile generation only if layer < max
        if layer < max_layers or layer >= 4:
            generate_tiles(original_img, row, col, layer)
        else:
            print(f"  ⏹️ No tile generation for layer_{layer}")

        # Step 3: Archive
        archive_dir = os.path.join(os.path.dirname(image_path), "archive")
        ensure_dir(archive_dir)
        archived_path = os.path.join(archive_dir, os.path.basename(image_path))
        shutil.move(image_path, archived_path)
        print(f"  📦 Archived original: {archived_path}")

    except Exception as e:
        print(f"❌ Error processing {image_path}: {e}")


def extract_layer_number(folder_name):
    match = re.search(r'layer_(\d+)', folder_name)
    return int(match.group(1)) if match else None


def main():
    print(f"🔍 Scanning originals from layer_0 to layer_{max_layers}...\n")
    for layer_dir in sorted(os.listdir(originals_root)):
        layer_path = os.path.join(originals_root, layer_dir)
        if not os.path.isdir(layer_path):
            continue

        layer_num = extract_layer_number(layer_dir)
        if layer_num is None or layer_num > max_layers:
            continue

        archive_dir = os.path.join(layer_path, "archive")
        ensure_dir(archive_dir)

        for filename in os.listdir(layer_path):
            if not filename.lower().endswith(".jpg"):
                continue
            full_path = os.path.join(layer_path, filename)
            if os.path.exists(os.path.join(archive_dir, filename)):
                print(f"⏭️ Skipping archived file: {filename}")
                continue
            process_image(full_path, layer_num)

    print("\n✅ Batch processing complete.")


if __name__ == "__main__":
    main()
# Out:
# 🔍 Scanning originals from layer_0 to layer_5...
#
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_1\0_0.jpg (layer_1)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_1\0_0.png
#   🔸 Generating 9 tiles for layer_2 (3×3)
#   🔸 Generating 81 tiles for layer_3 (9×9)
#   🔸 Generating 729 tiles for layer_4 (27×27)
#   🔸 Generating 6561 tiles for layer_5 (81×81)
#   📦 Archived original: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_1\archive\0_0.jpg
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_1\0_1.jpg (layer_1)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_1\0_1.png
#   🔸 Generating 9 tiles for layer_2 (3×3)
#   🔸 Generating 81 tiles for layer_3 (9×9)
#   🔸 Generating 729 tiles for layer_4 (27×27)
#   🔸 Generating 6561 tiles for layer_5 (81×81)
#   📦 Archived original: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_1\archive\0_1.jpg
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_1\0_2.jpg (layer_1)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_1\0_2.png
#   🔸 Generating 9 tiles for layer_2 (3×3)
#   🔸 Generating 81 tiles for layer_3 (9×9)
#   🔸 Generating 729 tiles for layer_4 (27×27)
#   🔸 Generating 6561 tiles for layer_5 (81×81)
#   📦 Archived original: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_1\archive\0_2.jpg
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_1\1_0.jpg (layer_1)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_1\1_0.png
#   🔸 Generating 9 tiles for layer_2 (3×3)
#   🔸 Generating 81 tiles for layer_3 (9×9)
#   🔸 Generating 729 tiles for layer_4 (27×27)
#   🔸 Generating 6561 tiles for layer_5 (81×81)
#   📦 Archived original: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_1\archive\1_0.jpg
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_1\1_1.jpg (layer_1)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_1\1_1.png
#   🔸 Generating 9 tiles for layer_2 (3×3)
#   🔸 Generating 81 tiles for layer_3 (9×9)
#   🔸 Generating 729 tiles for layer_4 (27×27)
#   🔸 Generating 6561 tiles for layer_5 (81×81)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_1\1_1.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_1\1_2.jpg (layer_1)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_1\1_2.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_1\2_0.jpg (layer_1)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_1\2_0.png
#   🔸 Generating 9 tiles for layer_2 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_1\2_0.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_1\2_1.jpg (layer_1)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_1\2_1.png
#   🔸 Generating 9 tiles for layer_2 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_1\2_1.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_1\2_2.jpg (layer_1)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_1\2_2.png
#   🔸 Generating 9 tiles for layer_2 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_1\2_2.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\0_4.jpg (layer_2)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_2\0_4.png
#   🔸 Generating 9 tiles for layer_3 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\0_4.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\0_5.jpg (layer_2)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_2\0_5.png
#   🔸 Generating 9 tiles for layer_3 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\0_5.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\0_6.jpg (layer_2)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_2\0_6.png
#   🔸 Generating 9 tiles for layer_3 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\0_6.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\13_12.jpg (layer_2)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\13_12.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\13_13.jpg (layer_2)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\13_13.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\13_14.jpg (layer_2)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\13_14.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\13_17.jpg (layer_2)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\13_17.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\14_12.jpg (layer_2)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\14_12.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\14_13.jpg (layer_2)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\14_13.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\14_14.jpg (layer_2)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\14_14.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\14_23.jpg (layer_2)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\14_23.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\15_13.jpg (layer_2)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\15_13.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\1_2.jpg (layer_2)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\1_2.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\1_4.jpg (layer_2)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_2\1_4.png
#   🔸 Generating 9 tiles for layer_3 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\1_4.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\2_4.jpg (layer_2)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_2\2_4.png
#   🔸 Generating 9 tiles for layer_3 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\2_4.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\2_7.jpg (layer_2)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_2\2_7.png
#   🔸 Generating 9 tiles for layer_3 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\2_7.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\2_8.jpg (layer_2)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_2\2_8.png
#   🔸 Generating 9 tiles for layer_3 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\2_8.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\3_0.jpg (layer_2)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_2\3_0.png
#   🔸 Generating 9 tiles for layer_3 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\3_0.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\3_1.jpg (layer_2)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_2\3_1.png
#   🔸 Generating 9 tiles for layer_3 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\3_1.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\3_2.jpg (layer_2)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_2\3_2.png
#   🔸 Generating 9 tiles for layer_3 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\3_2.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\3_3.jpg (layer_2)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\3_3.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\3_4.jpg (layer_2)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_2\3_4.png
#   🔸 Generating 9 tiles for layer_3 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\3_4.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\3_5.jpg (layer_2)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_2\3_5.png
#   🔸 Generating 9 tiles for layer_3 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\3_5.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\3_6.jpg (layer_2)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_2\3_6.png
#   🔸 Generating 9 tiles for layer_3 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\3_6.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\3_7.jpg (layer_2)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\3_7.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\3_8_1.jpg (layer_2)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\3_8_1.jpg: too many values to unpack (expected 2)
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\4_0.jpg (layer_2)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\4_0.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\4_1.jpg (layer_2)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\4_1.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\4_2.jpg (layer_2)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_2\4_2.png
#   🔸 Generating 9 tiles for layer_3 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\4_2.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\4_3.jpg (layer_2)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\4_3.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\4_5.jpg (layer_2)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_2\4_5.png
#   🔸 Generating 9 tiles for layer_3 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\4_5.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\4_6.jpg (layer_2)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\4_6.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\4_7.jpg (layer_2)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_2\4_7.png
#   🔸 Generating 9 tiles for layer_3 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\4_7.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\4_8.jpg (layer_2)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\4_8.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\5_0.jpg (layer_2)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\5_0.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\5_1.jpg (layer_2)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_2\5_1.png
#   🔸 Generating 9 tiles for layer_3 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\5_1.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\5_2.jpg (layer_2)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_2\5_2.png
#   🔸 Generating 9 tiles for layer_3 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\5_2.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\5_3.jpg (layer_2)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_2\5_3.png
#   🔸 Generating 9 tiles for layer_3 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\5_3.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\5_4.jpg (layer_2)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_2\5_4.png
#   🔸 Generating 9 tiles for layer_3 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\5_4.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\5_5.jpg (layer_2)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_2\5_5.png
#   🔸 Generating 9 tiles for layer_3 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\5_5.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\5_6.jpg (layer_2)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_2\5_6.png
#   🔸 Generating 9 tiles for layer_3 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\5_6.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\5_7.jpg (layer_2)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\5_7.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\5_8.jpg (layer_2)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\5_8.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\6_0.jpg (layer_2)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\6_0.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\6_1.jpg (layer_2)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\6_1.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\6_4.jpg (layer_2)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_2\6_4.png
#   🔸 Generating 9 tiles for layer_3 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\6_4.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\6_5.jpg (layer_2)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_2\6_5.png
#   🔸 Generating 9 tiles for layer_3 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\6_5.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\6_6.jpg (layer_2)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_2\6_6.png
#   🔸 Generating 9 tiles for layer_3 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\6_6.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\6_7.jpg (layer_2)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\6_7.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\6_8.jpg (layer_2)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_2\6_8.png
#   🔸 Generating 9 tiles for layer_3 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\6_8.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\7_0.jpg (layer_2)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_2\7_0.png
#   🔸 Generating 9 tiles for layer_3 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\7_0.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\7_1.jpg (layer_2)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_2\7_1.png
#   🔸 Generating 9 tiles for layer_3 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\7_1.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\7_4.jpg (layer_2)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_2\7_4.png
#   🔸 Generating 9 tiles for layer_3 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\7_4.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\7_5.jpg (layer_2)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_2\7_5.png
#   🔸 Generating 9 tiles for layer_3 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\7_5.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\7_6.jpg (layer_2)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_2\7_6.png
#   🔸 Generating 9 tiles for layer_3 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\7_6.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\7_7.jpg (layer_2)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_2\7_7.png
#   🔸 Generating 9 tiles for layer_3 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\7_7.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\7_8.jpg (layer_2)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_2\7_8.png
#   🔸 Generating 9 tiles for layer_3 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\7_8.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\8_0.jpg (layer_2)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_2\8_0.png
#   🔸 Generating 9 tiles for layer_3 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\8_0.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\8_1.jpg (layer_2)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_2\8_1.png
#   🔸 Generating 9 tiles for layer_3 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\8_1.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\8_4.jpg (layer_2)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_2\8_4.png
#   🔸 Generating 9 tiles for layer_3 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\8_4.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\8_6.jpg (layer_2)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_2\8_6.png
#   🔸 Generating 9 tiles for layer_3 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\8_6.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\8_7.jpg (layer_2)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_2\8_7.png
#   🔸 Generating 9 tiles for layer_3 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\8_7.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\8_8.jpg (layer_2)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_2\8_8.png
#   🔸 Generating 9 tiles for layer_3 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_2\8_8.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_3\0_17.jpg (layer_3)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_3\0_17.png
#   🔸 Generating 9 tiles for layer_4 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_3\0_17.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_3\0_18.jpg (layer_3)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_3\0_18.png
#   🔸 Generating 9 tiles for layer_4 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_3\0_18.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_3\10_19.jpg (layer_3)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_3\10_19.png
#   🔸 Generating 9 tiles for layer_4 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_3\10_19.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_3\11_2.jpg (layer_3)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_3\11_2.png
#   🔸 Generating 9 tiles for layer_4 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_3\11_2.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_3\11_23.jpg (layer_3)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_3\11_23.png
#   🔸 Generating 9 tiles for layer_4 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_3\11_23.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_3\16_3.jpg (layer_3)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_3\16_3.png
#   🔸 Generating 9 tiles for layer_4 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_3\16_3.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_3\19_13.jpg (layer_3)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_3\19_13.png
#   🔸 Generating 9 tiles for layer_4 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_3\19_13.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_3\19_17.jpg (layer_3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_3\19_17.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_3\19_18.jpg (layer_3)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_3\19_18.png
#   🔸 Generating 9 tiles for layer_4 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_3\19_18.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_3\20_13.jpg (layer_3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_3\20_13.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_3\20_17.jpg (layer_3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_3\20_17.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_3\21_13.jpg (layer_3)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_3\21_13.png
#   🔸 Generating 9 tiles for layer_4 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_3\21_13.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_3\22_0.jpg (layer_3)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_3\22_0.png
#   🔸 Generating 9 tiles for layer_4 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_3\22_0.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_3\22_1.jpg (layer_3)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_3\22_1.png
#   🔸 Generating 9 tiles for layer_4 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_3\22_1.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_3\22_12.jpg (layer_3)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_3\22_12.png
#   🔸 Generating 9 tiles for layer_4 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_3\22_12.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_3\22_14.jpg (layer_3)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_3\22_14.png
#   🔸 Generating 9 tiles for layer_4 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_3\22_14.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_3\22_16.jpg (layer_3)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_3\22_16.png
#   🔸 Generating 9 tiles for layer_4 (3×3)
#   🔸 Generating 81 tiles for layer_5 (9×9)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_3\22_16.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_3\26_23.jpg (layer_3)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_3\26_23.png
#   🔸 Generating 9 tiles for layer_4 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_3\26_23.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_3\3_8.jpg (layer_3)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_3\3_8.png
#   🔸 Generating 9 tiles for layer_4 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_3\3_8.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_3\6_13.jpg (layer_3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_3\6_13.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_3\9_13.jpg (layer_3)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_3\9_13.png
#   🔸 Generating 9 tiles for layer_4 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_3\9_13.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_4\10_25.jpg (layer_4)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_4\10_25.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_4\18_40.jpg (layer_4)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_4\18_40.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_4\19_40.jpg (layer_4)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_4\19_40.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_4\33_71.jpg (layer_4)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_4\33_71.png
#   🔸 Generating 9 tiles for layer_5 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_4\33_71.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_4\40_36.jpg (layer_4)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_4\40_36.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_4\40_40.jpg (layer_4)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_4\40_40.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_4\40_52.jpg (layer_4)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_4\40_52.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_4\41_40.jpg (layer_4)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_4\41_40.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_4\42_40.jpg (layer_4)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_4\42_40.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_4\44_70.jpg (layer_4)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_4\44_70.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_4\46_40.jpg (layer_4)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_4\46_40.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_4\50_11.jpg (layer_4)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_4\50_11.png
#   🔸 Generating 9 tiles for layer_5 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_4\50_11.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_4\57_39.jpg (layer_4)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_4\57_39.png
#   🔸 Generating 9 tiles for layer_5 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_4\57_39.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_4\57_55.jpg (layer_4)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_4\57_55.png
#   🔸 Generating 9 tiles for layer_5 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_4\57_55.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_4\58_52.jpg (layer_4)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_4\58_52.png
#   🔸 Generating 9 tiles for layer_5 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_4\58_52.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_4\58_54.jpg (layer_4)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_4\58_54.png
#   🔸 Generating 9 tiles for layer_5 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_4\58_54.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_4\60_40.jpg (layer_4)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_4\60_40.png
#   🔸 Generating 9 tiles for layer_5 (3×3)
#   🔸 Generating 81 tiles for layer_6 (9×9)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_4\60_40.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_4\66_2.jpg (layer_4)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_4\66_2.png
#   🔸 Generating 9 tiles for layer_5 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_4\66_2.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_4\67_50.jpg (layer_4)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_4\67_50.png
#   🔸 Generating 9 tiles for layer_5 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_4\67_50.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_4\68_4.jpg (layer_4)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_4\68_4.png
#   🔸 Generating 9 tiles for layer_5 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_4\68_4.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_4\69_25.jpg (layer_4)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_4\69_25.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_4\9_25.jpg (layer_4)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_4\9_25.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_5\121_109.jpg (layer_5)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_5\121_109.png
#   🔸 Generating 9 tiles for layer_6 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_5\121_109.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_5\121_121.jpg (layer_5)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_5\121_121.png
#   🔸 Generating 9 tiles for layer_6 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_5\121_121.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_5\122_156.jpg (layer_5)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_5\122_156.png
#   🔸 Generating 9 tiles for layer_6 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_5\122_156.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_5\123_121.jpg (layer_5)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_5\123_121.png
#   🔸 Generating 9 tiles for layer_6 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_5\123_121.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_5\128_121.jpg (layer_5)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_5\128_121.png
#   🔸 Generating 9 tiles for layer_6 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_5\128_121.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_5\140_120.jpg (layer_5)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_5\140_120.png
#   🔸 Generating 9 tiles for layer_6 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_5\140_120.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_5\151_33.jpg (layer_5)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_5\151_33.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_5\151_34.jpg (layer_5)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_5\151_34.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_5\180_122.jpg (layer_5)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_5\180_122.png
#   🔸 Generating 9 tiles for layer_6 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_5\180_122.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_5\181_120.jpg (layer_5)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_5\181_120.png
#   🔸 Generating 9 tiles for layer_6 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_5\181_120.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_5\181_122.jpg (layer_5)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_5\181_122.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_5\205_12.jpg (layer_5)
#   ✅ Resized saved: C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\tiles\layer_5\205_12.png
#   🔸 Generating 9 tiles for layer_6 (3×3)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_5\205_12.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_5\56_121.jpg (layer_5)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_5\56_121.jpg: [Errno 28] No space left on device
#
# 🖼️ Processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_5\57_121.jpg (layer_5)
# ❌ Error processing C:\Users\brian\Documents\Tiled Images\stacked_dimensions_2_midjourney\originals\layer_5\57_121.jpg: [Errno 28] No space left on device
#
# ✅ Batch processing complete.
